# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = requests.get('https://api.covid19india.org/data.json').json()

# %%
rows = df['cases_time_series']

# %%
df = pd.DataFrame()

# %%
for r in rows:
    df = df.append(r,ignore_index=True)

# %%
df = df.set_index('date')

# %%
df.index = [i + '2020' for i in df.index]

# %%
df.index = df.index.str.strip()

# %%
df.index = pd.to_datetime(df.index)

# %%
df = df.astype(int)

# %%
df.plot(logy=True)

# %%
df['dailyactive']= df['dailyconfirmed'] - df['dailyrecovered'] - df['dailydeceased']

# %%
df['totalactive'] = df['totalconfirmed'] - df['totalrecovered'] - df['totaldeceased']

# %%
df.plot(x='totalconfirmed',y='dailyconfirmed',kind='scatter')

# %%
import numpy as np
import operator
from sklearn.preprocessing import PolynomialFeatures 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X = np.array(df['totalconfirmed'])
y = np.array(df['dailyconfirmed'])

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=2)

# %%
pf = PolynomialFeatures(degree=4)
X_t = pf.fit_transform(X_train.reshape(-1,1))

# %%
LR = LinearRegression()
LR.fit(X_t,y_train)
X_test_t = pf.transform(X_test.reshape(-1,1))
y_pred = LR.predict(X_test_t)

# %%
print(f'Train Score: {LR.score(X_t,y_train)}')
print(f'Test Score: {LR.score(X_test_t,y_test)}')
# Out:
# Train Score: 0.9797727564202082
# Test Score: 0.9893959183099199

# %%
plt.scatter(X_test,y_pred,s=25,c='r')
plt.scatter(X_test,y_test,s=25,c='b')
plt.legend(['y_pred','y_test'])
plt.title('Test Set')
plt.show()

# %%
X_plot = np.array([x*1000 for x in range(70)])
y_plot = LR.predict(pf.transform(X_plot.reshape(-1,1)))

plt.scatter(X,y,s=20,c='black')
y_today = [i*100 for i in range(40)]
x_today = [X[-1] for i in range(40)]
plt.plot(X_plot,y_plot,color='orange')
plt.plot(x_today,y_today,color='red')
plt.legend(['Prediction','Today','Actual values'])

plt.title('Confirmed Cases vs Total Cases')
plt.show()

# %%
from IPython.display import HTML
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/54XLXg4fYsc?rel=0&amp;controls=0&amp;showinfo=0" frameborder="0" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/54XLXg4fYsc?rel=0&amp;controls=0&amp;showinfo=0" frameborder="0" allowfullscreen></iframe>
